# %% [markdown]
# <a href="https://colab.research.google.com/github/XXXayubend/ChatBot/blob/master/Visualisationipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd#importation des library
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Visualisation de données

# %%
data=pd.read_csv('/content/vgsales.csv')
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#afficher les valeurs manquantes
data.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
#supprimer les valeurs manquantes
data=data.dropna(how='all')
data.shape
# Out:
# (16598, 11)

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Compter les NaN par colonne
nan_count = data.isna().sum()
nan_count
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data_interpolated = data.interpolate()
# Out:
# <ipython-input-38-2de15769b5a1>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data_interpolated = data.interpolate()

# %%
data_interpolated
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# Compter les NaN par colonne
nan_count = data_interpolated.isna().sum()
nan_count
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %% [markdown]
# Bar Plot pour compoarer les ventes globales par plateform

# %%
platform_sales = data_interpolated.groupby('Platform')['Global_Sales'].sum().reset_index()
#Trier les données par ventes globales
platform_sales = platform_sales.sort_values(by='Global_Sales', ascending=True)

plt.figure(figsize=(12, 6))
sns.barplot(x='Global_Sales', y='Platform', data=platform_sales, palette='viridis')
plt.title('Ventes Globales par Plateforme', fontsize=16)
plt.xlabel('Ventes Globales (en millions)', fontsize=12)
plt.ylabel('Plateforme', fontsize=12)

plt.show()
# Out:
# <ipython-input-46-3dd06176001c>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales', y='Platform', data=platform_sales, palette='viridis')

# %% [markdown]
# On remarque que (NG, WS, TG16, 3DO, GG, PCFX) sont des platformes finie et pour cela on raison que n'est pas important de fourni des jeux pour ces platforme

# %% [markdown]
# Bar Plot pour comparer les vente par genre

# %%
platform_sales = data_interpolated.groupby('Genre')['Global_Sales'].sum().reset_index()
#Trier les données par ventes globales
platform_sales = platform_sales.sort_values(by='Global_Sales', ascending=True)

plt.figure(figsize=(12, 6))
sns.barplot(x='Global_Sales', y='Genre', data=platform_sales, palette='viridis')
plt.title('Ventes Globales par Genre', fontsize=16)
plt.xlabel('Ventes Globales (en millions)', fontsize=12)
plt.ylabel('Plateforme', fontsize=12)

plt.show()
# Out:
# <ipython-input-47-e63817a870a4>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Global_Sales', y='Genre', data=platform_sales, palette='viridis')

# %% [markdown]
# Comparer les ventes par région

# %% [markdown]
# On remarque que les jeux (action, sports, shooter,role-playing, platform) sont les plus jeux rentable

# %%
# Préparer les données pour le graphique à barres groupées
sales_data = data_interpolated[['Name', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
sales_data.set_index('Name', inplace=True)

# Définir la largeur des barres
bar_width = 0.2
index = np.arange(len(sales_data))

# Créer un graphique à barres empilées
sales_data.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='viridis')

# Ajouter des titres et des labels
plt.title('Ventes par Région (Empilées)', fontsize=16)
plt.xlabel('Jeux', fontsize=12)
plt.ylabel('Ventes (en millions)', fontsize=12)
plt.legend(title='Régions', bbox_to_anchor=(1.05, 1), loc='upper left')

# Afficher le graphique
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-52-ade8a892007b>:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# Nuage de point pour visualiser la relation entre les ventes en NA_sales and EU_sales

# %%
# Créer le nuage de points
plt.figure(figsize=(10, 6))
plt.scatter(data_interpolated['NA_Sales'], data_interpolated['EU_Sales'], alpha=0.7)

# Ajouter des titres et des labels
plt.title('Relation entre les ventes en NA et en EU', fontsize=16)
plt.xlabel('Ventes en Europe (EU Sales)', fontsize=12)
plt.ylabel('Ventes en Amérique du Nord (NA Sales)', fontsize=12)

# Afficher la grille
plt.grid()

# Afficher le graphique
plt.show()

# %% [markdown]
# On remarque que les points sont très concentrés dans une zone particulière du graphique c-a-d la majorité des ventrs se situent dans ce plage,et les pooints se regrouper le long d'une ligne ascendente c-a-d une corrélation positive entre les ventes en NA et EU , en fin je remarque qu'il ya une point très éloignés indique des jeux qui sont un succés exceptionnel dans une région et non dans l'autre

# %% [markdown]
# Nuage entre JP et EU

# %%
# Créer le nuage de points
plt.figure(figsize=(10, 6))
plt.scatter(data_interpolated['JP_Sales'], data_interpolated['EU_Sales'], alpha=0.7)

# Ajouter des titres et des labels
plt.title('Relation entre les ventes en JP et en EU', fontsize=16)
plt.xlabel('Ventes en Europe (EU Sales)', fontsize=12)
plt.ylabel('Ventes en Japon (JP Sales)', fontsize=12)

# Afficher la grille
plt.grid()

# Afficher le graphique
plt.show()

# %%
total_sales = {
    'NA_Sales': data_interpolated['NA_Sales'].sum(),
    'EU_Sales': data_interpolated['EU_Sales'].sum(),
    'JP_Sales': data_interpolated['JP_Sales'].sum(),
    'Other_Sales': data_interpolated['Other_Sales'].sum()
}
labels = total_sales.keys()
sizes = total_sales.values()
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode = (0.1, 0, 0, 0)

plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Répartition des ventes de jeux vidéo par région', fontsize=16)
plt.axis('equal')  # Pour s'assurer que le diagramme est un cercle
plt.show()

# %% [markdown]
# Distributuion des ventes Box Plot

# %%
# Vérifiez les types de données
print(data_interpolated.dtypes)

# Affichez des statistiques descriptives
print(data_interpolated[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].describe())
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object
#            NA_Sales      EU_Sales      JP_Sales   Other_Sales  Global_Sales
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean       0.264667      0.146652      0.077782      0.048063      0.537441
# std        0.816683      0.505351      0.309291      0.188588      1.555028
# min        0.000000      0.000000      0.000000      0.000000      0.010000
# 25%        0.000000      0.000000      0.000000      0.000000      0.060000
# 50%        0.080000      0.020000      0.000000      0.010000      0.170000
# 75%        0.240000      0.110000      0.040000      0.040000      0.470000
# ...

# %%
# Vérifiez les valeurs manquantes
print(data_interpolated.isnull().sum())
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %%
# Visualisez la distribution avec un histogramme
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.histplot(data_interpolated['NA_Sales'], bins=30)
plt.title('Distribution of NA Sales')
plt.xlabel('Sales (in millions)')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Supposons que vous avez déjà chargé et nettoyé votre dataset
# data_interpolated = pd.read_csv('path_to_your_interpolated_dataset.csv')

# Vérifiez les types de données et les valeurs manquantes
print(data_interpolated.dtypes)
print(data_interpolated.isnull().sum())

# Créer un DataFrame long pour les ventes
sales_data = pd.melt(data_interpolated,
                     value_vars=['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
                     var_name='Region', value_name='Sales')

# Créer le box plot avec Seaborn
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y='Sales', data=sales_data)

# Personnaliser le graphique
plt.title('Box Plot of Video Game Sales by Region')
plt.ylabel('Sales (in millions)')
plt.xlabel('Region')
plt.grid(axis='y')

# Afficher le graphique
plt.show()
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %% [markdown]
# Je remarque l'abscence de boite le Q1 , Q3 , IQR et whiskers ce qui signiifie que les donnée sont trés homogénes , les points qui sont en dehors indique des jeux qui en un succés exp ou des echecs notables , les boites pour les vnetes en NA est plus grand que Other_sales cela indique les jeux sont vendent en NA mieux

# %% [markdown]
# Heatmap

# %%
numerical_features = data_interpolated.select_dtypes(include=['number'])
corr = numerical_features.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Matrice de Corrélation des Jeux Vidéo')
plt.show()

# %% [markdown]
# je remarque que NA et EU ont une correlation positive avec global sales et on peut le classifiée par ça 0 à 0.3 : Corrélation faible
# 0.3 à 0.7 : Corrélation modérée
# 0.7 à 1 : Corrélation forte on raison aussi que NA et EU sont les deux région sont un marché clé pour les jeux vidéos aussi RANK ET YEAR sont deux correlation negative on peut le supprimer ainsi que global sales car elle est pour simplifier le model
